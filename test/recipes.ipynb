# %% [markdown]
# <a href="https://colab.research.google.com/github/rub-ksv/time-series/blob/main/test/recipes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time, pytz
from datetime import datetime

num_recipes = 500
# now as dictionary
recipes2 = {'Asia-Bowl mit Wildreis und scharfem Brokkoli (Hello Fresh)':1,
           'Asiatische Hähnchenbrust mit Edamame (Hello Fresh)':1,
           'BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh)':2,
           'Beef-Burger mit Chimichurri (Hello Fresh)':1,
           'Blitzschnelle Käsespätzlepfanne mit Bacon (Hello Fresh)':2,
           'Briam! Griechisches Ofengemüse mit Grillkäse (Hello Fresh)':1,
           'Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh)':2,
           'Burritos mit Hähnchen, Guacamole und Bohnen (Hello Fresh)':1,
           'Burritos mit BBQ-Hackfleisch und Käse (Hello Fresh)':1,
           'Caesar Salad Wrap mit Hähnchen (Hello Fresh)':2,
           'Cheeseburger mit verstecktem Gemüse (Hello Fresh)':3,
           'Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh)':1.5,
           'Flammkuchen mit Bacon und Honig (Hello Fresh)':2,
           'Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh)':3,
           'Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh)':3,
           'Hähnchenbrust gefüllt mit Basilikum-Frischkäse (Hello Fresh)':1.5,
           'Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh)':1,
           'Hähnchen-Wrap mit karamelisiertem Bacon (Hello Fresh)':2,
           'Halloumi mit Tikka-Masala-Veggies & Avocado (Hello Fresh)':2,
           'Haloumi-Wrap mit Chimichurri (Hello Fresh)':1,
           'Haselnussspätzle mit Schweinefilet (Hello Fresh)':2,
           'Honig-gebackener Camembert mit Pekannüssen (Hello Fresh)':2, 
           'Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh)':2,
           'Käsige Hackbällchen mit Rahmchampignons (Hello Fresh)':2.5,
           'Käsige Pfannkuchen mit Jägersauce (Hello Fresh)':1.5,
           'Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh)':1.5,
           'Mandel-Ziegenkäse auf Linsensalat (Hello Fresh)':1,
           'Maxi-Ravioli mit Tomate-Mozzarella-Füllung (Hello Fresh)':1,
           'Mexican Bake mit würzigem Hähnchen (Hello Fresh)':1.5,
           'Rinderhackbällchen Tsukune-Style (Hello Fresh)':1,
           'Schweinefilet süßsauer (Hello Fresh)':1,
           'Schweinefilets mit Zwiebelsauce (Hello Fresh)':1.5,
           'Schweinemedaillons mit Kräuterbutter (Hello Fresh)':3,
           'Seehecht in Spinat-Sahne-Sauce (Hello Fresh)':1,
           'Spätzle mit Bacon (Hello Fresh)':3,
           'Sweet-Chili-Kokos-Nudeln (Hello Fresh)':2,
           'Tacos mit Süßkartoffel und Chorizo (Hello Fresh)':2.5,
           'Tandoori-Blumenkohl in tomatiger Dalsauce (Hello Fresh)':1.5,
           'Tapas-Platte mit selbstgemachter Mojo Rojo (Hello Fresh)':1,
           'Tex-Mex-Maiscremesuppe (Hello Fresh)':1,
           'Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh)':1.5,
           'Veganes Massaman-Curry (Hello Fresh)':3.5,
           'Würziges Harissa-Hähnchen (Hello Fresh)':3, 
           'Würzig-feurige Halloumi-Tacos (Hello Fresh)':2,
           'Würziges Schweinefilet mit Mandelpesto (Hello Fresh)':2,
           'Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh)':2,
           'Indisches TK-Essen':4,'Indisches Glas':2,
           'Chili-Chicken-TK':2,'Thai Glas':2,'Kartoffeln mit Backfisch':1,'Tacos':3,
           'Quesedillas':3,'Tortilla mit Brokkoli':2,'Kartoffeln mit Rührei':2,
           'Sweet & Sour Chicken (Chefkoch)':1,'Herzhafte Waffeln mit Frischkäsedip (Papier)':1,
           'Streetfood Waffel-Sandwiches mit knusprigem Hähnchen (Papier)':1.5,'Falafel-Teller':2,
           'Nudelauflauf':2,'Käse-Suppe':4,'Spaghetti Carbonara':3,'Spaghetti Bolognese':2,
           'Nudeln Arrabiata':4,'Haloumi-Burger':3.5,
           'Kartoffeln m. veg. Schnitzel':2,
           'Kürbissuppe (Chefkoch)':1,'Kartoffelcurry mit Paprika und veg. Geschnetzeltem':2,
           'Kartoffelsuppe mit Würstchen':2,'Kartoffeln mit Chilie-Dippers':3,
           'Chipotle Chickpea Tacos (Tasty)':2,'Easy-Peasy Potato Curry (Tasty)':2,
           'Cauliflower Walnut Burritos (Tasty)':1,'Chicken Alfredo Penne (Tasty)':2,
           'Chicken Fajita Pasta (Tasty)':1, 'Veggie Chicken Fajita Pasta (Tasty)':1,
           'Roasted Butternut Squash Soup (Tasty)':1, 'Spanish Omelette (Tasty)':1,
           'Cajun chicken pasta (Pioneer woman)':2}


def sample_recipe(recipes,sum):
  c = np.random.random() * sum
  previous = 0.0
  for r in recipes:
    if c > previous and c <= recipes[r]:
      break
    previous = recipes[r]
  print('%s value %f rand c %f' % (r, recipes[r],c))
  #print(r)



w_recipes = recipes2
sum = 0
for r in recipes2:
  sum += recipes2[r]
  w_recipes[r] = sum
print(sum)
#print(w_recipes)

# datetime object containing current date and time
zone = pytz.timezone("Europe/Berlin")
now = datetime.now(tz=zone)
# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	
# create random seed
t = int(time.time())
np.random.seed(t)

for idx in range(num_recipes):
  sample_recipe(w_recipes, sum)
# Out:
# 149.5
# date and time = 11/04/2022 11:13:39
# Indisches TK-Essen value 85.500000 rand c 85.485471
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.037516
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 133.630309
# Halloumi mit Tikka-Masala-Veggies & Avocado (Hello Fresh) value 33.000000 rand c 31.298667
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 72.417357
# Tandoori-Blumenkohl in tomatiger Dalsauce (Hello Fresh) value 65.500000 rand c 65.156469
# Burritos mit BBQ-Hackfleisch und Käse (Hello Fresh) value 12.000000 rand c 11.411049
# Tortilla mit Brokkoli value 100.500000 rand c 100.470092
# Thai Glas value 91.500000 rand c 90.552102
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 136.037120
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 40.937033
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.920160
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.363863
# Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh) value 29.000000 rand c 28.911926
# Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh) value 10.000000 rand c 9.500012
# Blitzschnelle Käsespätzlepfanne mit Bacon (Hello Fresh) value 7.000000 rand c 6.193018
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 18.095012
# Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh) value 69.000000 rand c 68.474696
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 54.611235
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.828971
# Mexican Bake mit würzigem Hähnchen (Hello Fresh) value 49.000000 rand c 48.672593
# Falafel-Teller value 108.000000 rand c 107.655947
# Nudeln Arrabiata value 123.000000 rand c 120.725258
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 134.898808
# BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh) value 4.000000 rand c 3.381678
# Tortilla mit Brokkoli value 100.500000 rand c 100.132790
# Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh) value 10.000000 rand c 8.641322
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 19.196520
# Chipotle Chickpea Tacos (Tasty) value 138.500000 rand c 137.686787
# Kartoffeln mit Rührei value 102.500000 rand c 101.430219
# Käse-Suppe value 114.000000 rand c 113.979918
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 37.094750
# Nudeln Arrabiata value 123.000000 rand c 121.903781
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 45.351249
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 52.566141
# Cauliflower Walnut Burritos (Tasty) value 141.500000 rand c 141.064538
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 126.991734
# Nudelauflauf value 110.000000 rand c 109.643928
# Streetfood Waffel-Sandwiches mit knusprigem Hähnchen (Papier) value 106.000000 rand c 105.893450
# Kartoffeln mit Rührei value 102.500000 rand c 100.612894
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.081672
# Quesedillas value 98.500000 rand c 98.177288
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 16.837198
# Nudelauflauf value 110.000000 rand c 108.005359
# Easy-Peasy Potato Curry (Tasty) value 140.500000 rand c 139.183158
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 71.469666
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 70.205020
# Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh) value 23.500000 rand c 23.065964
# Würziges Schweinefilet mit Mandelpesto (Hello Fresh) value 79.500000 rand c 79.005669
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 69.764760
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 56.748513
# BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh) value 4.000000 rand c 2.879823
# Tex-Mex-Maiscremesuppe (Hello Fresh) value 67.500000 rand c 67.147388
# Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh) value 69.000000 rand c 67.688328
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 133.827856
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 54.487139
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 19.628233
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 18.760066
# Würzig-feurige Halloumi-Tacos (Hello Fresh) value 77.500000 rand c 76.340223
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 13.260368
# BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh) value 4.000000 rand c 3.448864
# Tacos value 95.500000 rand c 95.461503
# Nudelauflauf value 110.000000 rand c 109.125830
# Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh) value 23.500000 rand c 20.871870
# Burritos mit Hähnchen, Guacamole und Bohnen (Hello Fresh) value 11.000000 rand c 10.149383
# Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh) value 81.500000 rand c 81.186983
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.855031
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.205126
# Streetfood Waffel-Sandwiches mit knusprigem Hähnchen (Papier) value 106.000000 rand c 104.792927
# Veggie Chicken Fajita Pasta (Tasty) value 145.500000 rand c 145.255309
# Spaghetti Carbonara value 117.000000 rand c 114.529269
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 69.707820
# Sweet & Sour Chicken (Chefkoch) value 103.500000 rand c 103.456080
# Kartoffeln mit Rührei value 102.500000 rand c 100.923488
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 19.762503
# Quesedillas value 98.500000 rand c 96.237975
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 25.448058
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 142.706408
# Halloumi mit Tikka-Masala-Veggies & Avocado (Hello Fresh) value 33.000000 rand c 32.835439
# Blitzschnelle Käsespätzlepfanne mit Bacon (Hello Fresh) value 7.000000 rand c 6.814115
# Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh) value 69.000000 rand c 68.712274
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 58.123335
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 132.713979
# Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh) value 40.000000 rand c 39.625591
# Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh) value 10.000000 rand c 9.296356
# Beef-Burger mit Chimichurri (Hello Fresh) value 5.000000 rand c 4.413863
# Haloumi-Wrap mit Chimichurri (Hello Fresh) value 34.000000 rand c 33.711297
# Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh) value 23.500000 rand c 21.621430
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 147.607436
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 15.098063
# Mandel-Ziegenkäse auf Linsensalat (Hello Fresh) value 46.500000 rand c 46.224606
# Mexican Bake mit würzigem Hähnchen (Hello Fresh) value 49.000000 rand c 48.978742
# Nudelauflauf value 110.000000 rand c 109.730380
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 148.523713
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.042583
# Chili-Chicken-TK value 89.500000 rand c 88.314348
# Spanish Omelette (Tasty) value 147.500000 rand c 147.096930
# Haloumi-Wrap mit Chimichurri (Hello Fresh) value 34.000000 rand c 33.019559
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 44.757753
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 36.009788
# Schweinefilet süßsauer (Hello Fresh) value 51.000000 rand c 50.163653
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 37.581338
# Kartoffeln mit Rührei value 102.500000 rand c 102.446734
# Käse-Suppe value 114.000000 rand c 113.422466
# Indisches Glas value 87.500000 rand c 86.671130
# Indisches TK-Essen value 85.500000 rand c 83.252818
# Indisches TK-Essen value 85.500000 rand c 85.041100
# Käse-Suppe value 114.000000 rand c 111.297011
# Nudeln Arrabiata value 123.000000 rand c 119.508760
# Kartoffeln mit Backfisch value 92.500000 rand c 92.289267
# Herzhafte Waffeln mit Frischkäsedip (Papier) value 104.500000 rand c 103.649729
# Burritos mit BBQ-Hackfleisch und Käse (Hello Fresh) value 12.000000 rand c 11.780478
# Chicken Fajita Pasta (Tasty) value 144.500000 rand c 143.802092
# Spaghetti Carbonara value 117.000000 rand c 114.098495
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 135.599207
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 45.440695
# Hähnchenbrust gefüllt mit Basilikum-Frischkäse (Hello Fresh) value 28.000000 rand c 27.324415
# Veggie Chicken Fajita Pasta (Tasty) value 145.500000 rand c 144.544238
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 18.261376
# Rinderhackbällchen Tsukune-Style (Hello Fresh) value 50.000000 rand c 49.449234
# Tacos value 95.500000 rand c 92.779176
# Mandel-Ziegenkäse auf Linsensalat (Hello Fresh) value 46.500000 rand c 46.046215
# Tacos value 95.500000 rand c 93.408010
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 141.742171
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 15.243418
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 148.484162
# Nudeln Arrabiata value 123.000000 rand c 121.375234
# Maxi-Ravioli mit Tomate-Mozzarella-Füllung (Hello Fresh) value 47.500000 rand c 46.825026
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 18.491209
# Veggie Chicken Fajita Pasta (Tasty) value 145.500000 rand c 145.087922
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 127.107686
# Mandel-Ziegenkäse auf Linsensalat (Hello Fresh) value 46.500000 rand c 46.388364
# Sweet-Chili-Kokos-Nudeln (Hello Fresh) value 61.500000 rand c 61.423846
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 20.245513
# Indisches Glas value 87.500000 rand c 86.694395
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 26.024327
# Quesedillas value 98.500000 rand c 96.477502
# Chili-Chicken-TK value 89.500000 rand c 88.047726
# Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh) value 81.500000 rand c 80.013345
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 134.154471
# Spaghetti Carbonara value 117.000000 rand c 116.892397
# Tacos value 95.500000 rand c 95.186389
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 53.462547
# Indisches TK-Essen value 85.500000 rand c 81.666272
# Mexican Bake mit würzigem Hähnchen (Hello Fresh) value 49.000000 rand c 48.740378
# Streetfood Waffel-Sandwiches mit knusprigem Hähnchen (Papier) value 106.000000 rand c 104.812769
# Chipotle Chickpea Tacos (Tasty) value 138.500000 rand c 137.006431
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 57.161218
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 63.442236
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 141.939670
# Thai Glas value 91.500000 rand c 90.517435
# Hähnchen-Wrap mit karamelisiertem Bacon (Hello Fresh) value 31.000000 rand c 30.471485
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 126.570630
# Maxi-Ravioli mit Tomate-Mozzarella-Füllung (Hello Fresh) value 47.500000 rand c 46.629460
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.215117
# Roasted Butternut Squash Soup (Tasty) value 146.500000 rand c 145.598964
# Veggie Chicken Fajita Pasta (Tasty) value 145.500000 rand c 144.997243
# Käsige Pfannkuchen mit Jägersauce (Hello Fresh) value 44.000000 rand c 42.701511
# Käsige Pfannkuchen mit Jägersauce (Hello Fresh) value 44.000000 rand c 43.524264
# Käse-Suppe value 114.000000 rand c 110.371590
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.204554
# Nudeln Arrabiata value 123.000000 rand c 119.878391
# Spaghetti Carbonara value 117.000000 rand c 115.618245
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.679671
# Haloumi-Wrap mit Chimichurri (Hello Fresh) value 34.000000 rand c 33.212236
# Mexican Bake mit würzigem Hähnchen (Hello Fresh) value 49.000000 rand c 47.579589
# Easy-Peasy Potato Curry (Tasty) value 140.500000 rand c 139.615927
# Kartoffeln mit Backfisch value 92.500000 rand c 92.208154
# Tacos value 95.500000 rand c 93.512212
# Spaghetti Carbonara value 117.000000 rand c 116.704008
# Spaghetti Bolognese value 119.000000 rand c 117.634089
# Beef-Burger mit Chimichurri (Hello Fresh) value 5.000000 rand c 4.784458
# Asia-Bowl mit Wildreis und scharfem Brokkoli (Hello Fresh) value 1.000000 rand c 0.196586
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 132.684140
# Nudeln Arrabiata value 123.000000 rand c 122.501479
# Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh) value 69.000000 rand c 67.904537
# Würziges Schweinefilet mit Mandelpesto (Hello Fresh) value 79.500000 rand c 78.244791
# Easy-Peasy Potato Curry (Tasty) value 140.500000 rand c 139.467509
# Asiatische Hähnchenbrust mit Edamame (Hello Fresh) value 2.000000 rand c 1.979806
# Tapas-Platte mit selbstgemachter Mojo Rojo (Hello Fresh) value 66.500000 rand c 65.583202
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 41.257304
# Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh) value 40.000000 rand c 39.913173
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 72.356342
# Asiatische Hähnchenbrust mit Edamame (Hello Fresh) value 2.000000 rand c 1.181767
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 44.530185
# Tacos value 95.500000 rand c 94.605821
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 57.534412
# Käse-Suppe value 114.000000 rand c 113.946039
# Falafel-Teller value 108.000000 rand c 106.943610
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.011883
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 37.790428
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 132.789105
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.740451
# Blitzschnelle Käsespätzlepfanne mit Bacon (Hello Fresh) value 7.000000 rand c 6.577360
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 74.343389
# Kartoffeln mit Backfisch value 92.500000 rand c 92.007563
# BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh) value 4.000000 rand c 2.538407
# Spaghetti Bolognese value 119.000000 rand c 118.721579
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 128.153789
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 142.908857
# Würziges Schweinefilet mit Mandelpesto (Hello Fresh) value 79.500000 rand c 78.148754
# Nudelauflauf value 110.000000 rand c 108.437181
# Käse-Suppe value 114.000000 rand c 112.304744
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 37.248905
# Tacos value 95.500000 rand c 93.120473
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.592839
# Beef-Burger mit Chimichurri (Hello Fresh) value 5.000000 rand c 4.060311
# Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh) value 29.000000 rand c 28.514021
# Cauliflower Walnut Burritos (Tasty) value 141.500000 rand c 140.777632
# Indisches TK-Essen value 85.500000 rand c 83.207513
# Käsige Pfannkuchen mit Jägersauce (Hello Fresh) value 44.000000 rand c 43.509024
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 54.999122
# Haloumi-Burger value 126.500000 rand c 125.382659
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 74.169876
# Chipotle Chickpea Tacos (Tasty) value 138.500000 rand c 137.885011
# Käse-Suppe value 114.000000 rand c 110.552133
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 19.922417
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 44.391357
# Quesedillas value 98.500000 rand c 95.660530
# Burritos mit BBQ-Hackfleisch und Käse (Hello Fresh) value 12.000000 rand c 11.435747
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 44.716250
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 36.901287
# Chili-Chicken-TK value 89.500000 rand c 88.364112
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 74.458982
# Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh) value 23.500000 rand c 23.354139
# Tortilla mit Brokkoli value 100.500000 rand c 99.183710
# Tandoori-Blumenkohl in tomatiger Dalsauce (Hello Fresh) value 65.500000 rand c 64.533312
# Kartoffeln mit Rührei value 102.500000 rand c 101.261211
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 132.077540
# Haselnussspätzle mit Schweinefilet (Hello Fresh) value 36.000000 rand c 34.604574
# Haselnussspätzle mit Schweinefilet (Hello Fresh) value 36.000000 rand c 34.183142
# Schweinefilets mit Zwiebelsauce (Hello Fresh) value 52.500000 rand c 51.713779
# Indisches TK-Essen value 85.500000 rand c 84.465262
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 13.708174
# Chipotle Chickpea Tacos (Tasty) value 138.500000 rand c 136.617404
# Spaghetti Carbonara value 117.000000 rand c 116.411994
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 142.091077
# Maxi-Ravioli mit Tomate-Mozzarella-Füllung (Hello Fresh) value 47.500000 rand c 47.286263
# Maxi-Ravioli mit Tomate-Mozzarella-Füllung (Hello Fresh) value 47.500000 rand c 47.092812
# Burritos mit BBQ-Hackfleisch und Käse (Hello Fresh) value 12.000000 rand c 11.864060
# Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh) value 69.000000 rand c 67.545069
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.281228
# Hähnchen-Wrap mit karamelisiertem Bacon (Hello Fresh) value 31.000000 rand c 30.205596
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 24.374847
# Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh) value 29.000000 rand c 28.773518
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 37.397921
# Tapas-Platte mit selbstgemachter Mojo Rojo (Hello Fresh) value 66.500000 rand c 65.642555
# Tortilla mit Brokkoli value 100.500000 rand c 100.286138
# Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh) value 10.000000 rand c 9.244429
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 142.968436
# BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh) value 4.000000 rand c 2.392271
# Tandoori-Blumenkohl in tomatiger Dalsauce (Hello Fresh) value 65.500000 rand c 64.864423
# Kürbissuppe (Chefkoch) value 129.500000 rand c 128.641338
# BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh) value 4.000000 rand c 2.629405
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 54.063057
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 126.795087
# Nudeln Arrabiata value 123.000000 rand c 122.769061
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 19.856404
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 18.076772
# Sweet-Chili-Kokos-Nudeln (Hello Fresh) value 61.500000 rand c 61.343949
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 41.359792
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.685357
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 149.405821
# Burritos mit BBQ-Hackfleisch und Käse (Hello Fresh) value 12.000000 rand c 11.121897
# Chicken Fajita Pasta (Tasty) value 144.500000 rand c 144.205906
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 36.662744
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 69.999936
# Nudelauflauf value 110.000000 rand c 109.305601
# Sweet-Chili-Kokos-Nudeln (Hello Fresh) value 61.500000 rand c 60.719785
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.659358
# Chipotle Chickpea Tacos (Tasty) value 138.500000 rand c 137.112105
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.776885
# Tandoori-Blumenkohl in tomatiger Dalsauce (Hello Fresh) value 65.500000 rand c 64.820749
# Tacos value 95.500000 rand c 94.673709
# Quesedillas value 98.500000 rand c 97.770776
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 149.364643
# Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh) value 40.000000 rand c 39.625300
# Tortilla mit Brokkoli value 100.500000 rand c 98.591371
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 128.046708
# Mexican Bake mit würzigem Hähnchen (Hello Fresh) value 49.000000 rand c 48.635912
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 57.009972
# Tacos value 95.500000 rand c 93.586105
# Indisches TK-Essen value 85.500000 rand c 85.398633
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 52.545457
# Nudelauflauf value 110.000000 rand c 108.127509
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 63.273053
# Haloumi-Burger value 126.500000 rand c 125.583152
# Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh) value 29.000000 rand c 28.420576
# Blitzschnelle Käsespätzlepfanne mit Bacon (Hello Fresh) value 7.000000 rand c 5.640516
# Kartoffeln mit Rührei value 102.500000 rand c 101.195756
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 40.114832
# Käse-Suppe value 114.000000 rand c 110.655936
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 72.565700
# Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh) value 69.000000 rand c 67.685882
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 41.517968
# Sweet-Chili-Kokos-Nudeln (Hello Fresh) value 61.500000 rand c 59.561895
# Hähnchenbrust gefüllt mit Basilikum-Frischkäse (Hello Fresh) value 28.000000 rand c 27.144976
# Cauliflower Walnut Burritos (Tasty) value 141.500000 rand c 140.687867
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 132.511712
# Schweinefilets mit Zwiebelsauce (Hello Fresh) value 52.500000 rand c 51.496034
# Mandel-Ziegenkäse auf Linsensalat (Hello Fresh) value 46.500000 rand c 45.889505
# Seehecht in Spinat-Sahne-Sauce (Hello Fresh) value 56.500000 rand c 56.325263
# Blitzschnelle Käsespätzlepfanne mit Bacon (Hello Fresh) value 7.000000 rand c 6.292319
# Tortilla mit Brokkoli value 100.500000 rand c 99.769249
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.886322
# Tacos value 95.500000 rand c 94.496979
# BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh) value 4.000000 rand c 2.880423
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 61.551543
# Schweinefilet süßsauer (Hello Fresh) value 51.000000 rand c 50.658433
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.910708
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 40.385968
# Haloumi-Burger value 126.500000 rand c 126.194286
# Würziges Schweinefilet mit Mandelpesto (Hello Fresh) value 79.500000 rand c 79.046515
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 54.327507
# Kartoffeln mit Rührei value 102.500000 rand c 101.954316
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.170685
# Chili-Chicken-TK value 89.500000 rand c 89.219298
# Sweet-Chili-Kokos-Nudeln (Hello Fresh) value 61.500000 rand c 60.958334
# Beef-Burger mit Chimichurri (Hello Fresh) value 5.000000 rand c 4.629014
# Tex-Mex-Maiscremesuppe (Hello Fresh) value 67.500000 rand c 67.145902
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 149.361388
# Haselnussspätzle mit Schweinefilet (Hello Fresh) value 36.000000 rand c 34.598481
# Chicken Fajita Pasta (Tasty) value 144.500000 rand c 143.729849
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 15.654146
# Beef-Burger mit Chimichurri (Hello Fresh) value 5.000000 rand c 4.690230
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 133.200423
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 134.104648
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 63.447575
# Asia-Bowl mit Wildreis und scharfem Brokkoli (Hello Fresh) value 1.000000 rand c 0.606823
# Flammkuchen mit Bacon und Honig (Hello Fresh) value 20.500000 rand c 19.292584
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 42.085381
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 16.992392
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 143.404245
# Tacos value 95.500000 rand c 95.116278
# Tandoori-Blumenkohl in tomatiger Dalsauce (Hello Fresh) value 65.500000 rand c 64.446379
# Easy-Peasy Potato Curry (Tasty) value 140.500000 rand c 139.278579
# Indisches TK-Essen value 85.500000 rand c 82.731447
# Chili-Chicken-TK value 89.500000 rand c 89.466323
# Seehecht in Spinat-Sahne-Sauce (Hello Fresh) value 56.500000 rand c 56.108363
# Vegane Bowl mit Sesam-Süßkartoffel (Hello Fresh) value 69.000000 rand c 67.669441
# Roasted Butternut Squash Soup (Tasty) value 146.500000 rand c 146.309077
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 73.305430
# Sweet & Sour Chicken (Chefkoch) value 103.500000 rand c 102.588488
# Haselnussspätzle mit Schweinefilet (Hello Fresh) value 36.000000 rand c 34.683015
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 57.310232
# Tortilla mit Brokkoli value 100.500000 rand c 99.391061
# Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh) value 23.500000 rand c 23.469743
# Mandel-Ziegenkäse auf Linsensalat (Hello Fresh) value 46.500000 rand c 46.416805
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 53.638145
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 44.434671
# Roasted Butternut Squash Soup (Tasty) value 146.500000 rand c 146.274860
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 58.997781
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 45.466422
# Seehecht in Spinat-Sahne-Sauce (Hello Fresh) value 56.500000 rand c 55.869682
# Cauliflower Walnut Burritos (Tasty) value 141.500000 rand c 141.387743
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 133.991907
# Streetfood Waffel-Sandwiches mit knusprigem Hähnchen (Papier) value 106.000000 rand c 104.525390
# Haselnussspätzle mit Schweinefilet (Hello Fresh) value 36.000000 rand c 35.658230
# Hähnchen-Wrap mit karamelisiertem Bacon (Hello Fresh) value 31.000000 rand c 29.314348
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 36.640620
# Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh) value 81.500000 rand c 79.751392
# Haloumi-Burger value 126.500000 rand c 125.680429
# Käse-Suppe value 114.000000 rand c 112.341583
# Burritos mit Hähnchen, Guacamole und Bohnen (Hello Fresh) value 11.000000 rand c 10.818774
# Hähnchen-Wrap mit karamelisiertem Bacon (Hello Fresh) value 31.000000 rand c 29.038302
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 54.068030
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 70.403893
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 59.191239
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.193914
# Quesedillas value 98.500000 rand c 96.739208
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.128859
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 148.901752
# Mandel-Ziegenkäse auf Linsensalat (Hello Fresh) value 46.500000 rand c 45.951609
# Briam! Griechisches Ofengemüse mit Grillkäse (Hello Fresh) value 8.000000 rand c 7.470685
# Nudeln Arrabiata value 123.000000 rand c 120.986661
# Haloumi-Wrap mit Chimichurri (Hello Fresh) value 34.000000 rand c 33.260602
# Thai Glas value 91.500000 rand c 91.413730
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 69.301707
# Würziges Schweinefilet mit Mandelpesto (Hello Fresh) value 79.500000 rand c 79.061940
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 142.606468
# Kartoffeln mit Rührei value 102.500000 rand c 100.942292
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 54.002719
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.679479
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 24.074835
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 59.427005
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.090496
# Haloumi-Burger value 126.500000 rand c 123.858511
# Schweinefilets mit Zwiebelsauce (Hello Fresh) value 52.500000 rand c 51.088684
# Herzhafte Waffeln mit Frischkäsedip (Papier) value 104.500000 rand c 104.254211
# Nudeln Arrabiata value 123.000000 rand c 121.918848
# Chili-Chicken-TK value 89.500000 rand c 87.815339
# Nudeln Arrabiata value 123.000000 rand c 120.786525
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 131.680967
# Kartoffeln mit Rührei value 102.500000 rand c 102.183241
# Tacos value 95.500000 rand c 93.460789
# Käsige Pfannkuchen mit Jägersauce (Hello Fresh) value 44.000000 rand c 43.983300
# Chili-Chicken-TK value 89.500000 rand c 87.665436
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 72.789377
# Indisches Glas value 87.500000 rand c 86.902355
# Quesedillas value 98.500000 rand c 96.447590
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 26.455003
# Easy-Peasy Potato Curry (Tasty) value 140.500000 rand c 138.504549
# Chipotle Chickpea Tacos (Tasty) value 138.500000 rand c 138.136414
# Hähnchen-Wrap mit karamelisiertem Bacon (Hello Fresh) value 31.000000 rand c 29.057239
# Schweinefilets mit Zwiebelsauce (Hello Fresh) value 52.500000 rand c 51.658903
# Mandel-Ziegenkäse auf Linsensalat (Hello Fresh) value 46.500000 rand c 45.766454
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 69.077603
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 74.627196
# Indisches TK-Essen value 85.500000 rand c 82.762300
# Hähnchen-Wrap mit karamelisiertem Bacon (Hello Fresh) value 31.000000 rand c 29.162716
# Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh) value 18.500000 rand c 17.276202
# Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh) value 40.000000 rand c 38.576514
# Nudelauflauf value 110.000000 rand c 109.250367
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 41.968138
# Schweinefilet süßsauer (Hello Fresh) value 51.000000 rand c 50.678826
# Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh) value 29.000000 rand c 28.263028
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 55.353874
# Käse-Suppe value 114.000000 rand c 110.292661
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.723838
# Tortilla mit Brokkoli value 100.500000 rand c 99.419635
# Honig-gebackener Camembert mit Pekannüssen (Hello Fresh) value 38.000000 rand c 37.951866
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 74.227591
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 24.873058
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.928290
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.103564
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 126.940866
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 24.214611
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 126.875699
# Mexican Bake mit würzigem Hähnchen (Hello Fresh) value 49.000000 rand c 48.369558
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 58.355850
# Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh) value 23.500000 rand c 23.262485
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 127.056521
# Spaghetti Bolognese value 119.000000 rand c 118.033926
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 128.072605
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 55.473945
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 149.153227
# Haselnussspätzle mit Schweinefilet (Hello Fresh) value 36.000000 rand c 34.318339
# Asiatische Hähnchenbrust mit Edamame (Hello Fresh) value 2.000000 rand c 1.710354
# Veggie Chicken Fajita Pasta (Tasty) value 145.500000 rand c 144.965552
# Käse-Suppe value 114.000000 rand c 110.203522
# Tacos value 95.500000 rand c 94.732317
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 133.294911
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 26.085979
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 42.228139
# Spanish Omelette (Tasty) value 147.500000 rand c 147.420202
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.692414
# Tandoori-Blumenkohl in tomatiger Dalsauce (Hello Fresh) value 65.500000 rand c 64.144741
# Käsige Hackbällchen mit Rahmchampignons (Hello Fresh) value 42.500000 rand c 40.383382
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 74.261792
# Quesedillas value 98.500000 rand c 96.574190
# Tortilla mit Brokkoli value 100.500000 rand c 100.058142
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.645736
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 24.386481
# Spätzle mit Bacon (Hello Fresh) value 59.500000 rand c 57.740827
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 127.689333
# Schweinemedaillons mit Kräuterbutter (Hello Fresh) value 55.500000 rand c 53.188508
# Kartoffelsuppe mit Würstchen value 133.500000 rand c 131.543343
# Thai Glas value 91.500000 rand c 91.428575
# Cajun chicken pasta (Pioneer woman) value 149.500000 rand c 148.555999
# Käsige Pfannkuchen mit Jägersauce (Hello Fresh) value 44.000000 rand c 43.808861
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 44.426739
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 134.317414
# Kartoffeln mit Chilie-Dippers value 136.500000 rand c 135.296424
# Haloumi-Wrap mit Chimichurri (Hello Fresh) value 34.000000 rand c 33.112329
# Tacos value 95.500000 rand c 93.124072
# Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh) value 81.500000 rand c 79.700196
# Chicken Alfredo Penne (Tasty) value 143.500000 rand c 142.491432
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 71.983692
# Chili-Chicken-TK value 89.500000 rand c 88.139169
# Kartoffeln m. veg. Schnitzel value 128.500000 rand c 127.435388
# Schweinefilets mit Zwiebelsauce (Hello Fresh) value 52.500000 rand c 52.305249
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 45.312259
# Veganes Massaman-Curry (Hello Fresh) value 72.500000 rand c 70.655585
# Seehecht in Spinat-Sahne-Sauce (Hello Fresh) value 56.500000 rand c 56.240910
# Würziges Schweinefilet mit Mandelpesto (Hello Fresh) value 79.500000 rand c 77.546250
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.420720
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 26.264154
# Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh) value 10.000000 rand c 9.891463
# Asia-Bowl mit Wildreis und scharfem Brokkoli (Hello Fresh) value 1.000000 rand c 0.595249
# Haloumi-Burger value 126.500000 rand c 124.580833
# Cheeseburger mit verstecktem Gemüse (Hello Fresh) value 17.000000 rand c 14.371815
# Würzig-feurige Halloumi-Tacos (Hello Fresh) value 77.500000 rand c 75.969284
# Nudeln Arrabiata value 123.000000 rand c 121.228513
# Haloumi-Burger value 126.500000 rand c 125.160899
# Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh) value 40.000000 rand c 38.359894
# Indisches TK-Essen value 85.500000 rand c 85.462394
# Caesar Salad Wrap mit Hähnchen (Hello Fresh) value 14.000000 rand c 12.838789
# Haselnussspätzle mit Schweinefilet (Hello Fresh) value 36.000000 rand c 35.986492
# Seehecht in Spinat-Sahne-Sauce (Hello Fresh) value 56.500000 rand c 56.407993
# Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh) value 81.500000 rand c 80.799206
# Spanish Omelette (Tasty) value 147.500000 rand c 147.158047
# Spaghetti Carbonara value 117.000000 rand c 115.312921
# Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh) value 45.500000 rand c 44.583981
# Schweinefilets mit Zwiebelsauce (Hello Fresh) value 52.500000 rand c 51.887396
# Käse-Suppe value 114.000000 rand c 113.540081
# Tacos mit Süßkartoffel und Chorizo (Hello Fresh) value 64.000000 rand c 62.527421
# Würziges Harissa-Hähnchen (Hello Fresh) value 75.500000 rand c 72.775602
# Indisches TK-Essen value 85.500000 rand c 85.439763
# Grüner Salat mit Ziegenkäse im Speckmantel (Hello Fresh) value 26.500000 rand c 25.432242
# Hähnchenbrust gefüllt mit Basilikum-Frischkäse (Hello Fresh) value 28.000000 rand c 26.673563

# %%
import numpy as np
import time, pytz
from datetime import datetime
recipes = ['Halloumi mit Tikka-Masala-Veggies & Avocado (Hello Fresh)',
           'Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh)',
           'Honig-gebackener Camembert mit Pekannüssen (Hello Fresh)', 
           'Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh)',
           'Sweet-Chili-Kokos-Nudeln (Hello Fresh)',
           'Schweinemedaillons mit Kräuterbutter (Hello Fresh)',
           'Asiatische Hähnchenbrust mit Edamame (Hello Fresh)',
           'Tex-Mex-Maiscremesuppe (Hello Fresh)',
           'Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh)',
           'Haloumi-Wrap mit Chimichurri (Hello Fresh)',
           'Haselnussspätzle mit Schweinefilet (Hello Fresh)',
           'Käsige Hackbällchen mit Rahmchampignons (Hello Fresh)',
           'Schweinefilet süßsauer (Hello Fresh)',
           'Tapas-Platte mit selbstgemachter Mojo Rojo (Hello Fresh)',
           'Mandel-Ziegenkäse auf Linsensalat (Hello Fresh)',
           'Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh)',
           'Seehecht in Spinat-Sahne-Sauce (Hello Fresh)',
           'Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh)',
           'Burritos mit Hähnchen, Guacamole und Bohnen (Hello Fresh)',
           'Briam! Griechisches Ofengemüse mit Grillkäse (Hello Fresh)',
           'Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh)',
           'BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh)',
           'Würzig-feurige Halloumi-Tacos (Hello Fresh)',
           'Cheeseburger mit verstecktem Gemüse (Hello Fresh)',
           'Cheeseburger mit verstecktem Gemüse (Hello Fresh)',
           'Harissa-Hähnchen (Hello Fresh)', 'Harissa-Hähnchen (Hello Fresh)',
           'Tacos mit Süßkartoffel und Chorizo (Hello Fresh)',
           'Tacos mit Süßkartoffel und Chorizo (Hello Fresh)',
           'Schweinefilet mit Zwiebelsauce (Hello Fresh)',
           'Schweinefilet mit Mandelpesto (Hello Fresh)',
           'Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh)',
           'Rinderhackbällchen Tsukune-Style (Hello Fresh)',
           'Beef-Burger mit Chimichurri (Hello Fresh)',
           'Spätzle mit Bacon (Hello Fresh)',
           'Käsespätzlepfanne mit Bacon (Hello Fresh)',
           'Flammkuchen mit Bacon und Honig (Hello Fresh)',
           'Hähnchen-Wrap mit Bacon (Hello Fresh)',
           'Veganes Massaman-Curry (Hello Fresh)','Veganes Massaman-Curry (Hello Fresh)',
           'Indisches TK-Essen','Indisches TK-Essen','Indisches Glas',
           'Chili-Chicken-TK','Thai Glas','Kartoffeln mit Backfisch','Tacos',
           'Quesedillas','Tortilla mit Brokkoli','Kartoffeln mit Rührei',
           'Sweet & Sour Chicken','Herzhafte Waffeln mit Frischkäsedip (Papier)',
           'Streetfood Waffel-Sandwiches mit knusprigem Hähnchen (Papier)','Falafel-Teller',
           'Nudelauflauf','Käse-Suppe','Spaghetti Carbonara','Spaghetti Bolognese',
           'Nudeln Arrabiata','Nudeln Arrabiata','Haloumi-Burger',
           'Kartoffeln m. veg. Schnitzel',
           'Kürbissuppe (Chefkoch)','Kartoffelcurry mit Paprika und veg. Geschnetzeltem',
           'Kartoffelsuppe mit Würstchen','Kartoffeln mit Chilie-Dippers',
           'Chipotle Chickpea Tacos (Tasty)','Potato curry (Tasty)',
           'Cauliflower Walnut Burritos (Tasty)','Chicken Alfredo Penne (Tasty)',
           'Chicken Fajita Pasta (Tasty)', 'Veggie Chicken Fajita Pasta (Tasty)',
           'Roasted Butternut Squash Soup (Tasty)', 'Spanish Omelette (Tasty)',
           'Cajun chicken pasta (Pioneer woman)']

# datetime object containing current date and time
zone = pytz.timezone("Europe/Berlin")
now = datetime.now(tz=zone)
# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)	
# create random seed
t = int(time.time())
np.random.seed(t)
l = len(recipes)
c = np.random.permutation(range(l))
i= 0
for idx in c:
  i=i+1
  print(str(i) + ' ' + recipes[idx])
# Out:
# date and time = 08/01/2022 18:27:47
# 1 Würzig-feurige Halloumi-Tacos (Hello Fresh)
# 2 Kartoffeln mit Rührei
# 3 Kartoffelcurry mit Paprika und veg. Geschnetzeltem
# 4 Hähnchenfilet in Honig-Zitronen-Marinade (Hello Fresh)
# 5 Tacos mit Süßkartoffel und Chorizo (Hello Fresh)
# 6 Kürbissuppe (Chefkoch)
# 7 Haselnussspätzle mit Schweinefilet (Hello Fresh)
# 8 BBQ-Rindfleischburger mit Bacon und Käse (Hello Fresh)
# 9 Käsige Hackbällchen mit Rahmchampignons (Hello Fresh)
# 10 Cauliflower Walnut Burritos (Tasty)
# 11 Harissa-Hähnchen (Hello Fresh)
# 12 Honig-Senf-Hähnchen mit Kürbispüree (Hello Fresh)
# 13 Schweinefilet mit Mandelpesto (Hello Fresh)
# 14 Sweet & Sour Chicken
# 15 Rinderhackbällchen Tsukune-Style (Hello Fresh)
# 16 Tex-Mex-Maiscremesuppe (Hello Fresh)
# 17 Indisches Glas
# 18 Spaghetti Carbonara
# 19 Cheeseburger mit verstecktem Gemüse (Hello Fresh)
# 20 Veggie Chicken Fajita Pasta (Tasty)
# 21 Schweinefilet mit Zwiebelsauce (Hello Fresh)
# 22 Mandel-Ziegenkäse auf Linsensalat (Hello Fresh)
# 23 Spanish Omelette (Tasty)
# 24 Asiatische Hähnchenbrust mit Edamame (Hello Fresh)
# 25 Tacos
# 26 Roasted Butternut Squash Soup (Tasty)
# 27 Chipotle Chickpea Tacos (Tasty)
# 28 Tapas-Platte mit selbstgemachter Mojo Rojo (Hello Fresh)
# 29 Cheeseburger mit verstecktem Gemüse (Hello Fresh)
# 30 Käse-Suppe
# 31 Herzhafte Waffeln mit Frischkäsedip (Papier)
# 32 Kartoffelsuppe mit Würstchen
# 33 Haloumi-Burger
# 34 Käsespätzlepfanne mit Bacon (Hello Fresh)
# 35 Schweinefilet süßsauer (Hello Fresh)
# 36 Streetfood Waffel-Sandwiches mit knusprigem Hähnchen (Papier)
# 37 Halloumi mit Tikka-Masala-Veggies & Avocado (Hello Fresh)
# 38 Thai Glas
# 39 Cajun chicken pasta (Pioneer woman)
# 40 Gebratene Schweinemedaillons in Zwiebel-Rahmsauce (Hello Fresh)
# 41 Burritos mit Hähnchen, Guacamole und Bohnen (Hello Fresh)
# 42 Ziegenkäsetaler getoppt mit Haselnüssen (Hello Fresh)
# 43 Seehecht in Spinat-Sahne-Sauce (Hello Fresh)
# 44 Falafel-Teller
# 45 Harissa-Hähnchen (Hello Fresh)
# 46 Kartoffeln mit Backfisch
# 47 Erdnuss-Kokos-Bowl mit Pak Choi (Hello Fresh)
# 48 Indisches TK-Essen
# 49 Sweet-Chili-Kokos-Nudeln (Hello Fresh)
# 50 Nudeln Arrabiata
# 51 Kartoffeln mit Chilie-Dippers
# 52 Nudeln Arrabiata
# 53 Hähnchen-Wrap mit Bacon (Hello Fresh)
# 54 Tortilla mit Brokkoli
# 55 Veganes Massaman-Curry (Hello Fresh)
# 56 Potato curry (Tasty)
# 57 Tacos mit Süßkartoffel und Chorizo (Hello Fresh)
# 58 Veganes Massaman-Curry (Hello Fresh)
# 59 Spätzle mit Bacon (Hello Fresh)
# 60 Honig-gebackener Camembert mit Pekannüssen (Hello Fresh)
# 61 Kürbissuppe mit Tomaten-Pesto-Schnecken (Hello Fresh)
# 62 Haloumi-Wrap mit Chimichurri (Hello Fresh)
# 63 Nudelauflauf
# 64 Chili-Chicken-TK
# 65 Briam! Griechisches Ofengemüse mit Grillkäse (Hello Fresh)
# 66 Beef-Burger mit Chimichurri (Hello Fresh)
# 67 Quesedillas
# 68 Kartoffeln m. veg. Schnitzel
# 69 Indisches TK-Essen
# 70 Spaghetti Bolognese
# 71 Chicken Fajita Pasta (Tasty)
# 72 Chicken Alfredo Penne (Tasty)
# 73 Schweinemedaillons mit Kräuterbutter (Hello Fresh)
# 74 Flammkuchen mit Bacon und Honig (Hello Fresh)
# 75 Bruschetta-Hähnchen mit Ofengemüse (Hello Fresh)
